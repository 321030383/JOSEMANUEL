# %% [markdown]
# <a href="https://colab.research.google.com/github/321030383/JOSEMANUEL/blob/main/GATO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a1=0
a2=0
a3=0
b1=0
b2=0
b3=0
c1=0
c2=0
c3=0

jugador1=input('Jugador uno ingrese la celda: ')
if(jugador1=="a1"):
  a1=1
if(jugador1=="a2"):
  a2=1
if(jugador1=="a3"):
  a3=1
if(jugador1=="b1"):
  b1=1
if(jugador1=="b2"):
  b2=1
if(jugador1=="b3"):
  b3=1
if(jugador1=="c1"):
  c1=1
if(jugador1=="c2"):
  c2=1
if(jugador1=="c3"):
  c3=1

jugador2=input('Jugador dos ingrese la celda: ')
if(jugador2=="a1"):
  a1=2
if(jugador2=="a2"):
  a2=2
if(jugador2=="a3"):
  a3=2
if(jugador2=="b1"):
  b1=2
if(jugador2=="b2"):
  b2=2
if(jugador2=="b3"):
  b3=2
if(jugador2=="c1"):
  c1=2
if(jugador2=="c2"):
  c2=2
if(jugador2=="c3"):
  c3=2


jugador1=input('Jugador uno ingrese la celda: ')
if(jugador1=="a1"):
  a1=1
if(jugador1=="a2"):
  a2=1
if(jugador1=="a3"):
  a3=1
if(jugador1=="b1"):
  b1=1
if(jugador1=="b2"):
  b2=1
if(jugador1=="b3"):
  b3=1
if(jugador1=="c1"):
  c1=1
if(jugador1=="c2"):
  c2=1
if(jugador1=="c3"):
  c3=1


jugador2=input('Jugador dos ingrese la celda: ')
if(jugador2=="a1"):
  a1=2
if(jugador2=="a2"):
  a2=2
if(jugador2=="a3"):
  a3=2
if(jugador2=="b1"):
  b1=2
if(jugador2=="b2"):
  b2=2
if(jugador2=="b3"):
  b3=2
if(jugador2=="c1"):
  c1=2
if(jugador2=="c2"):
  c2=2
if(jugador2=="c3"):
  c3=2



jugador1=input('Jugador uno ingrese la celda: ')
if(jugador1=="a1"):
  a1=1
if(jugador1=="a2"):
  a2=1
if(jugador1=="a3"):
  a3=1
if(jugador1=="b1"):
  b1=1
if(jugador1=="b2"):
  b2=1
if(jugador1=="b3"):
  b3=1
if(jugador1=="c1"):
  c1=1
if(jugador1=="c2"):
  c2=1
if(jugador1=="c3"):
  c3=1


if((a1==1) and (a2==1)and(a3==1)):
  print("Gana jugador 1")


jugador2=input('Jugador dos ingrese la celda: ')
if(jugador2=="a1"):
  a1=2
if(jugador2=="a2"):
  a2=2
if(jugador2=="a3"):
  a3=2
if(jugador2=="b1"):
  b1=2
if(jugador2=="b2"):
  b2=2
if(jugador2=="b3"):
  b3=2
if(jugador2=="c1"):
  c1=2
if(jugador2=="c2"):
  c2=2
if(jugador2=="c3"):
  c3=2


if((a1==1) and (b2==1)and(c3==1)):
  print("Gana jugador 1")

jugador1=input('Jugador uno ingrese la celda: ')
if(jugador1=="a1"):
  a1=1
if(jugador1=="a2"):
  a2=1
if(jugador1=="a3"):
  a3=1
if(jugador1=="b1"):
  b1=1
if(jugador1=="b2"):
  b2=1
if(jugador1=="b3"):
  b3=1
if(jugador1=="c1"):
  c1=1
if(jugador1=="c2"):
  c2=1
if(jugador1=="c3"):
  c3=1
if((a2==1) and (b2==1)and(c2==1)):
  print("Gana jugador 1")
if((a2==2) and (b2==2)and(c2==2)):
  print("Gana jugador 2")
  
  jugador2=input('Jugador dos ingrese la celda: ')
if(jugador2=="a1"):
  a1=2
if(jugador2=="a2"):
  a2=2
if(jugador2=="a3"):
  a3=2
if(jugador2=="b1"):
  b1=2
if(jugador2=="b2"):
  b2=2
if(jugador2=="b3"):
  b3=2
if(jugador2=="c1"):
  c1=2
if(jugador2=="c2"):
  c2=2
if(jugador2=="c3"):
  c3=2
